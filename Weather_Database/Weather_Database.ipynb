# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
#Use the citypy module to detemine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
#Import the requests library
import requests
#Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#Loop through all the cities in our list.
for i, city in enumerate(cities):
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    #Log the URL,record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 to the record count
    record_count += 1
    
    #Run an API request for each of the cities
    try:
        #parse the JSON and retreve data.
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | plettenberg bay
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | synya
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | yanaul
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 1 | husavik
# Processing Record 16 of Set 1 | matay
# Processing Record 17 of Set 1 | svelgen
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | gold coast
# Processing Record 22 of Set 1 | marathon
# Processing Record 23 of Set 1 | kailua
# Processing Record 24 of Set 1 | novyy urengoy
# Processing Record 25 of Set 1 | port moresby
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | prince rupert
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | meulaboh
# Processing Record 32 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | sri aman
# Processing Record 36 of Set 1 | fairbanks
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | buala
# Processing Record 39 of Set 1 | nanakuli
# Processing Record 40 of Set 1 | puerto ayora
# Processing Record 41 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | ulladulla
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | villa bisono
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | chicama
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | bara
# Processing Record 2 of Set 2 | nova olimpia
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | bourail
# Processing Record 5 of Set 2 | shingu
# Processing Record 6 of Set 2 | tessalit
# Processing Record 7 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 2 | tuatapere
# Processing Record 9 of Set 2 | daru
# Processing Record 10 of Set 2 | lapua
# Processing Record 11 of Set 2 | cabedelo
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | ust-omchug
# Processing Record 14 of Set 2 | monrovia
# Processing Record 15 of Set 2 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 2 | punta arenas
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 2 | olinda
# Processing Record 20 of Set 2 | bizhbulyak
# Processing Record 21 of Set 2 | namibe
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | yulara
# Processing Record 24 of Set 2 | antalaha
# Processing Record 25 of Set 2 | atsipopoulon
# Processing Record 26 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | santa cruz
# Processing Record 30 of Set 2 | oberstdorf
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | broken hill
# Processing Record 33 of Set 2 | taltal
# Processing Record 34 of Set 2 | los llanos de aridane
# Processing Record 35 of Set 2 | boyany
# Processing Record 36 of Set 2 | locri
# Processing Record 37 of Set 2 | high level
# Processing Record 38 of Set 2 | sambava
# Processing Record 39 of Set 2 | pincher creek
# Processing Record 40 of Set 2 | udon thani
# Processing Record 41 of Set 2 | kibala
# Processing Record 42 of Set 2 | bhadra
# Processing Record 43 of Set 2 | tiksi
# Processing Record 44 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 2 | acarau
# Processing Record 46 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 2 | alice springs
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | matara
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | santa cruz del sur
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | hovd
# Processing Record 4 of Set 3 | berlevag
# Processing Record 5 of Set 3 | khormuj
# City not found. Skipping...
# Processing Record 6 of Set 3 | hami
# Processing Record 7 of Set 3 | narsaq
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | dori
# Processing Record 10 of Set 3 | sirjan
# Processing Record 11 of Set 3 | victoria
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | jiuquan
# Processing Record 14 of Set 3 | saint-francois
# Processing Record 15 of Set 3 | sorland
# Processing Record 16 of Set 3 | casino
# Processing Record 17 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | ivanovka
# Processing Record 21 of Set 3 | cayenne
# Processing Record 22 of Set 3 | norsup
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | vondrozo
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | longyearbyen
# Processing Record 28 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 3 | burnie
# Processing Record 30 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 3 | lasa
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | kaitangata
# Processing Record 34 of Set 3 | cherskiy
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | salinas
# Processing Record 37 of Set 3 | omboue
# Processing Record 38 of Set 3 | byron bay
# Processing Record 39 of Set 3 | torbay
# Processing Record 40 of Set 3 | caravelas
# Processing Record 41 of Set 3 | nanlong
# Processing Record 42 of Set 3 | bagotville
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | cockburn town
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | fengrun
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | raub
# Processing Record 50 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | komsomolskiy
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | bhainsdehi
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | devils lake
# Processing Record 7 of Set 4 | pevek
# Processing Record 8 of Set 4 | azangaro
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | white rock
# Processing Record 11 of Set 4 | dalianwan
# Processing Record 12 of Set 4 | shahr-e kord
# Processing Record 13 of Set 4 | bethel
# Processing Record 14 of Set 4 | barrow
# Processing Record 15 of Set 4 | clyde river
# Processing Record 16 of Set 4 | mwinilunga
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 4 | rundu
# Processing Record 20 of Set 4 | tuktoyaktuk
# Processing Record 21 of Set 4 | povolzhskiy
# Processing Record 22 of Set 4 | bubaque
# Processing Record 23 of Set 4 | pangai
# Processing Record 24 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 4 | riyadh
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | vanderhoof
# Processing Record 28 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 4 | avarua
# Processing Record 30 of Set 4 | dukstas
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | nuevo progreso
# Processing Record 33 of Set 4 | komsomolets
# Processing Record 34 of Set 4 | sironj
# Processing Record 35 of Set 4 | yerbogachen
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | guerrero negro
# Processing Record 38 of Set 4 | ponta delgada
# Processing Record 39 of Set 4 | bulungu
# Processing Record 40 of Set 4 | porto novo
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | kenai
# Processing Record 43 of Set 4 | am timan
# Processing Record 44 of Set 4 | keti bandar
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | bonthe
# Processing Record 47 of Set 4 | saint-augustin
# Processing Record 48 of Set 4 | tianpeng
# Processing Record 49 of Set 4 | felipe carrillo puerto
# Processing Record 50 of Set 4 | tsienyane
# City not found. Skipping...
# Processing Record 1 of Set 5 | gamba
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 5 | bonavista
# Processing Record 5 of Set 5 | constitucion
# Processing Record 6 of Set 5 | bugac
# Processing Record 7 of Set 5 | sekoma
# Processing Record 8 of Set 5 | sucre
# Processing Record 9 of Set 5 | buluang
# Processing Record 10 of Set 5 | maldonado
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | vila franca do campo
# Processing Record 13 of Set 5 | hithadhoo
# Processing Record 14 of Set 5 | manggar
# Processing Record 15 of Set 5 | thessalon
# Processing Record 16 of Set 5 | ler
# Processing Record 17 of Set 5 | beloha
# Processing Record 18 of Set 5 | klaksvik
# Processing Record 19 of Set 5 | felanitx
# Processing Record 20 of Set 5 | talnakh
# Processing Record 21 of Set 5 | tura
# Processing Record 22 of Set 5 | ariquemes
# Processing Record 23 of Set 5 | dingle
# Processing Record 24 of Set 5 | black diamond
# Processing Record 25 of Set 5 | kahului
# Processing Record 26 of Set 5 | nome
# Processing Record 27 of Set 5 | jacqueville
# Processing Record 28 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 5 | hermanus
# Processing Record 30 of Set 5 | fort nelson
# Processing Record 31 of Set 5 | hvide sande
# Processing Record 32 of Set 5 | morro bay
# Processing Record 33 of Set 5 | cap malheureux
# Processing Record 34 of Set 5 | new norfolk
# Processing Record 35 of Set 5 | cuamba
# Processing Record 36 of Set 5 | maumere
# Processing Record 37 of Set 5 | solnechnyy
# Processing Record 38 of Set 5 | tigil
# Processing Record 39 of Set 5 | atuona
# Processing Record 40 of Set 5 | padang
# Processing Record 41 of Set 5 | naantali
# Processing Record 42 of Set 5 | say
# Processing Record 43 of Set 5 | margate
# Processing Record 44 of Set 5 | kula
# Processing Record 45 of Set 5 | pakxan
# Processing Record 46 of Set 5 | rapar
# Processing Record 47 of Set 5 | palmer
# Processing Record 48 of Set 5 | brattvag
# Processing Record 49 of Set 5 | castro
# Processing Record 50 of Set 5 | tame
# Processing Record 1 of Set 6 | verdalsora
# City not found. Skipping...
# Processing Record 2 of Set 6 | katsuura
# Processing Record 3 of Set 6 | ust-shonosha
# Processing Record 4 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 5 of Set 6 | kumo
# Processing Record 6 of Set 6 | key west
# Processing Record 7 of Set 6 | chalatenango
# Processing Record 8 of Set 6 | martil
# Processing Record 9 of Set 6 | rio gallegos
# Processing Record 10 of Set 6 | ugoofaaru
# Processing Record 11 of Set 6 | beroroha
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | vestmannaeyjar
# Processing Record 14 of Set 6 | akdepe
# Processing Record 15 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 6 | odweyne
# Processing Record 17 of Set 6 | turukhansk
# Processing Record 18 of Set 6 | abnub
# Processing Record 19 of Set 6 | sobolevo
# Processing Record 20 of Set 6 | zhigansk
# Processing Record 21 of Set 6 | sao filipe
# Processing Record 22 of Set 6 | yar-sale
# Processing Record 23 of Set 6 | chardara
# Processing Record 24 of Set 6 | kaeo
# Processing Record 25 of Set 6 | okhotsk
# Processing Record 26 of Set 6 | ornskoldsvik
# Processing Record 27 of Set 6 | enid
# Processing Record 28 of Set 6 | melfi
# Processing Record 29 of Set 6 | saldanha
# Processing Record 30 of Set 6 | harwich
# Processing Record 31 of Set 6 | zyryanka
# Processing Record 32 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 34 of Set 6 | redlands
# Processing Record 35 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 6 | sturgis
# Processing Record 37 of Set 6 | providencia
# Processing Record 38 of Set 6 | mastic beach
# Processing Record 39 of Set 6 | xining
# Processing Record 40 of Set 6 | coahuayana
# Processing Record 41 of Set 6 | coihaique
# Processing Record 42 of Set 6 | geraldton
# Processing Record 43 of Set 6 | calabozo
# Processing Record 44 of Set 6 | labuhan
# Processing Record 45 of Set 6 | goch
# Processing Record 46 of Set 6 | kalavrita
# City not found. Skipping...
# Processing Record 47 of Set 6 | pietarsaari
# Processing Record 48 of Set 6 | mount isa
# Processing Record 49 of Set 6 | boquira
# Processing Record 50 of Set 6 | isla mujeres
# Processing Record 1 of Set 7 | talgar
# Processing Record 2 of Set 7 | ahipara
# Processing Record 3 of Set 7 | pombal
# Processing Record 4 of Set 7 | waingapu
# Processing Record 5 of Set 7 | imbituba
# Processing Record 6 of Set 7 | paamiut
# Processing Record 7 of Set 7 | allen
# Processing Record 8 of Set 7 | havre-saint-pierre
# Processing Record 9 of Set 7 | elk city
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | touros
# Processing Record 12 of Set 7 | vermilion
# Processing Record 13 of Set 7 | taoudenni
# Processing Record 14 of Set 7 | nantucket
# Processing Record 15 of Set 7 | teya
# Processing Record 16 of Set 7 | christchurch
# Processing Record 17 of Set 7 | barra dos coqueiros
# Processing Record 18 of Set 7 | pauini
# Processing Record 19 of Set 7 | nicoya
# Processing Record 20 of Set 7 | hun
# Processing Record 21 of Set 7 | kui buri
# Processing Record 22 of Set 7 | eureka
# Processing Record 23 of Set 7 | kalanchak
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | ozernovskiy
# Processing Record 26 of Set 7 | korla
# Processing Record 27 of Set 7 | champerico
# Processing Record 28 of Set 7 | san juan de uraba
# Processing Record 29 of Set 7 | rantepao
# Processing Record 30 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 31 of Set 7 | hadejia
# Processing Record 32 of Set 7 | luderitz
# Processing Record 33 of Set 7 | bloemhof
# Processing Record 34 of Set 7 | jalu
# Processing Record 35 of Set 7 | papara
# Processing Record 36 of Set 7 | dawlatabad
# Processing Record 37 of Set 7 | makat
# Processing Record 38 of Set 7 | deputatskiy
# Processing Record 39 of Set 7 | seydi
# Processing Record 40 of Set 7 | arlit
# Processing Record 41 of Set 7 | hirara
# Processing Record 42 of Set 7 | nargana
# Processing Record 43 of Set 7 | do rud
# City not found. Skipping...
# Processing Record 44 of Set 7 | kindersley
# Processing Record 45 of Set 7 | ventspils
# Processing Record 46 of Set 7 | benguela
# Processing Record 47 of Set 7 | franca
# Processing Record 48 of Set 7 | hobyo
# Processing Record 49 of Set 7 | souillac
# Processing Record 50 of Set 7 | santhia
# Processing Record 1 of Set 8 | araouane
# Processing Record 2 of Set 8 | merauke
# Processing Record 3 of Set 8 | aksehir
# Processing Record 4 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 8 | aviles
# Processing Record 6 of Set 8 | jacareacanga
# Processing Record 7 of Set 8 | atar
# Processing Record 8 of Set 8 | erzin
# Processing Record 9 of Set 8 | neiafu
# Processing Record 10 of Set 8 | bandiagara
# Processing Record 11 of Set 8 | bahia blanca
# Processing Record 12 of Set 8 | leningradskiy
# Processing Record 13 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 14 of Set 8 | provideniya
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | alekseyevsk
# Processing Record 17 of Set 8 | tlacote el bajo
# Processing Record 18 of Set 8 | banda aceh
# Processing Record 19 of Set 8 | campbell river
# Processing Record 20 of Set 8 | umm lajj
# Processing Record 21 of Set 8 | yarmouth
# Processing Record 22 of Set 8 | evensk
# Processing Record 23 of Set 8 | praia
# Processing Record 24 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 25 of Set 8 | urucara
# Processing Record 26 of Set 8 | oussouye
# Processing Record 27 of Set 8 | nanortalik
# Processing Record 28 of Set 8 | mitsamiouli
# Processing Record 29 of Set 8 | whitehorse
# Processing Record 30 of Set 8 | pisco
# Processing Record 31 of Set 8 | buenos aires
# Processing Record 32 of Set 8 | bemidji
# Processing Record 33 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | sitka
# Processing Record 35 of Set 8 | gladstone
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | sovetskiy
# Processing Record 38 of Set 8 | conceicao do araguaia
# Processing Record 39 of Set 8 | bend
# Processing Record 40 of Set 8 | thinadhoo
# Processing Record 41 of Set 8 | san joaquin
# Processing Record 42 of Set 8 | santiago
# Processing Record 43 of Set 8 | laguna
# Processing Record 44 of Set 8 | enshi
# Processing Record 45 of Set 8 | guatire
# Processing Record 46 of Set 8 | kodiak
# Processing Record 47 of Set 8 | xuanhua
# Processing Record 48 of Set 8 | yinchuan
# Processing Record 49 of Set 8 | vallenar
# Processing Record 50 of Set 8 | kopychyntsi
# Processing Record 1 of Set 9 | aswan
# Processing Record 2 of Set 9 | lata
# Processing Record 3 of Set 9 | felsoszentivan
# Processing Record 4 of Set 9 | porto walter
# Processing Record 5 of Set 9 | vao
# Processing Record 6 of Set 9 | qandala
# Processing Record 7 of Set 9 | menongue
# Processing Record 8 of Set 9 | anadyr
# Processing Record 9 of Set 9 | wasilla
# Processing Record 10 of Set 9 | kavaratti
# Processing Record 11 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 13 of Set 9 | iracoubo
# Processing Record 14 of Set 9 | shimoda
# Processing Record 15 of Set 9 | duz
# City not found. Skipping...
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | port blair
# Processing Record 18 of Set 9 | bengkulu
# Processing Record 19 of Set 9 | durazno
# Processing Record 20 of Set 9 | avera
# Processing Record 21 of Set 9 | camana
# Processing Record 22 of Set 9 | klyuchi
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | otane
# Processing Record 25 of Set 9 | ponta do sol
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | lucea
# Processing Record 28 of Set 9 | akonolinga
# Processing Record 29 of Set 9 | brus laguna
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | coos bay
# Processing Record 32 of Set 9 | port hardy
# Processing Record 33 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 34 of Set 9 | bandarbeyla
# Processing Record 35 of Set 9 | lamu
# Processing Record 36 of Set 9 | dicabisagan
# Processing Record 37 of Set 9 | marhaura
# Processing Record 38 of Set 9 | kitimat
# Processing Record 39 of Set 9 | tambopata
# Processing Record 40 of Set 9 | pochutla
# Processing Record 41 of Set 9 | dalbeattie
# Processing Record 42 of Set 9 | cheremkhovo
# Processing Record 43 of Set 9 | saskylakh
# Processing Record 44 of Set 9 | kieta
# Processing Record 45 of Set 9 | tabuk
# Processing Record 46 of Set 9 | awbari
# Processing Record 47 of Set 9 | chulman
# Processing Record 48 of Set 9 | makubetsu
# Processing Record 49 of Set 9 | churapcha
# Processing Record 50 of Set 9 | thompson
# Processing Record 1 of Set 10 | lagoa
# Processing Record 2 of Set 10 | capao da canoa
# Processing Record 3 of Set 10 | jibuti
# Processing Record 4 of Set 10 | borba
# Processing Record 5 of Set 10 | hofn
# Processing Record 6 of Set 10 | great bend
# Processing Record 7 of Set 10 | jhol
# Processing Record 8 of Set 10 | alofi
# Processing Record 9 of Set 10 | hambantota
# Processing Record 10 of Set 10 | alekseyevka
# Processing Record 11 of Set 10 | iwanai
# Processing Record 12 of Set 10 | centerville
# Processing Record 13 of Set 10 | kawalu
# Processing Record 14 of Set 10 | aksarka
# Processing Record 15 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 10 | bjelovar
# Processing Record 17 of Set 10 | henties bay
# Processing Record 18 of Set 10 | abbeyleix
# Processing Record 19 of Set 10 | balykshi
# Processing Record 20 of Set 10 | tabas
# Processing Record 21 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 10 | maturin
# Processing Record 23 of Set 10 | panguna
# Processing Record 24 of Set 10 | along
# Processing Record 25 of Set 10 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 10 | mineros
# Processing Record 27 of Set 10 | togur
# Processing Record 28 of Set 10 | charters towers
# Processing Record 29 of Set 10 | sulangan
# Processing Record 30 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 10 | atherton
# Processing Record 32 of Set 10 | hernani
# Processing Record 33 of Set 10 | te anau
# Processing Record 34 of Set 10 | inta
# Processing Record 35 of Set 10 | san quintin
# Processing Record 36 of Set 10 | sydney mines
# Processing Record 37 of Set 10 | villazon
# Processing Record 38 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 39 of Set 10 | manokwari
# Processing Record 40 of Set 10 | iberia
# Processing Record 41 of Set 10 | rio grande
# Processing Record 42 of Set 10 | yabelo
# Processing Record 43 of Set 10 | thoen
# Processing Record 44 of Set 10 | turkistan
# Processing Record 45 of Set 10 | muzhi
# Processing Record 46 of Set 10 | alyangula
# Processing Record 47 of Set 10 | alberton
# Processing Record 48 of Set 10 | maniitsoq
# Processing Record 49 of Set 10 | oranjestad
# Processing Record 50 of Set 10 | bjerringbro
# Processing Record 1 of Set 11 | pringsewu
# Processing Record 2 of Set 11 | brae
# Processing Record 3 of Set 11 | wilmington
# Processing Record 4 of Set 11 | saryg-sep
# Processing Record 5 of Set 11 | samarai
# Processing Record 6 of Set 11 | iskateley
# Processing Record 7 of Set 11 | vega de alatorre
# Processing Record 8 of Set 11 | smoky lake
# Processing Record 9 of Set 11 | mana
# Processing Record 10 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 11 | buchanan
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 14 of Set 11 | alausi
# Processing Record 15 of Set 11 | persianovskiy
# Processing Record 16 of Set 11 | mouila
# Processing Record 17 of Set 11 | san lazaro
# Processing Record 18 of Set 11 | snasa
# Processing Record 19 of Set 11 | huanuco
# Processing Record 20 of Set 11 | zhezkazgan
# Processing Record 21 of Set 11 | mastung
# Processing Record 22 of Set 11 | trnava
# Processing Record 23 of Set 11 | tarakan
# Processing Record 24 of Set 11 | ibra
# Processing Record 25 of Set 11 | honiara
# Processing Record 26 of Set 11 | bontang
# Processing Record 27 of Set 11 | tete
# Processing Record 28 of Set 11 | kokkola
# Processing Record 29 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 11 | chaumont-gistoux
# Processing Record 32 of Set 11 | angoram
# Processing Record 33 of Set 11 | kungurtug
# Processing Record 34 of Set 11 | panaba
# Processing Record 35 of Set 11 | talara
# Processing Record 36 of Set 11 | kodinar
# Processing Record 37 of Set 11 | viedma
# Processing Record 38 of Set 11 | ancud
# Processing Record 39 of Set 11 | amboasary
# Processing Record 40 of Set 11 | dubai
# Processing Record 41 of Set 11 | mareeba
# Processing Record 42 of Set 11 | abu samrah
# Processing Record 43 of Set 11 | yima
# Processing Record 44 of Set 11 | raposa
# Processing Record 45 of Set 11 | aykhal
# Processing Record 46 of Set 11 | walla walla
# Processing Record 47 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 48 of Set 11 | pacifica
# Processing Record 49 of Set 11 | oktyabrskiy
# Processing Record 50 of Set 11 | codrington
# Processing Record 1 of Set 12 | malinovoye ozero
# Processing Record 2 of Set 12 | chadan
# Processing Record 3 of Set 12 | loreto
# Processing Record 4 of Set 12 | takoradi
# Processing Record 5 of Set 12 | faya
# Processing Record 6 of Set 12 | banjar
# Processing Record 7 of Set 12 | aasiaat
# Processing Record 8 of Set 12 | sosnovo-ozerskoye
# Processing Record 9 of Set 12 | camargo
# Processing Record 10 of Set 12 | van
# Processing Record 11 of Set 12 | tirat karmel
# Processing Record 12 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 12 | murovani kurylivtsi
# Processing Record 14 of Set 12 | liverpool
# Processing Record 15 of Set 12 | pemba
# Processing Record 16 of Set 12 | prim decembrie
# Processing Record 17 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 18 of Set 12 | sibolga
# Processing Record 19 of Set 12 | tchollire
# Processing Record 20 of Set 12 | ingham
# Processing Record 21 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 22 of Set 12 | ouegoa
# Processing Record 23 of Set 12 | high rock
# Processing Record 24 of Set 12 | haines junction
# Processing Record 25 of Set 12 | kudahuvadhoo
# Processing Record 26 of Set 12 | guanica
# Processing Record 27 of Set 12 | linchuan
# City not found. Skipping...
# Processing Record 28 of Set 12 | sao francisco do sul
# Processing Record 29 of Set 12 | gunnedah
# Processing Record 30 of Set 12 | lokomotivnyy
# Processing Record 31 of Set 12 | rawson
# Processing Record 32 of Set 12 | sur
# Processing Record 33 of Set 12 | nemuro
# Processing Record 34 of Set 12 | grindavik
# Processing Record 35 of Set 12 | muros
# Processing Record 36 of Set 12 | millinocket
# Processing Record 37 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 12 | ostersund
# Processing Record 39 of Set 12 | liku
# Processing Record 40 of Set 12 | kruisfontein
# Processing Record 41 of Set 12 | naze
# Processing Record 42 of Set 12 | inhambane
# Processing Record 43 of Set 12 | ipixuna
# Processing Record 44 of Set 12 | tual
# Processing Record 45 of Set 12 | mizpe ramon
# City not found. Skipping...
# Processing Record 46 of Set 12 | maragogi
# Processing Record 47 of Set 12 | asht
# City not found. Skipping...
# Processing Record 48 of Set 12 | amapa
# Processing Record 49 of Set 12 | ciamis
# Processing Record 50 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 13 | karlstad
# Processing Record 2 of Set 13 | dodge city
# Processing Record 3 of Set 13 | deep river
# Processing Record 4 of Set 13 | kingaroy
# Processing Record 5 of Set 13 | kodinsk
# Processing Record 6 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 13 | tavda
# Processing Record 8 of Set 13 | yago
# Processing Record 9 of Set 13 | beira
# Processing Record 10 of Set 13 | cabo san lucas
# Processing Record 11 of Set 13 | pizarro
# Processing Record 12 of Set 13 | saint-joseph
# Processing Record 13 of Set 13 | la ronge
# Processing Record 14 of Set 13 | mangrol
# Processing Record 15 of Set 13 | vomp
# Processing Record 16 of Set 13 | aklavik
# Processing Record 17 of Set 13 | sonepur
# Processing Record 18 of Set 13 | santiago del estero
# Processing Record 19 of Set 13 | tiznit
# Processing Record 20 of Set 13 | nizwa
# Processing Record 21 of Set 13 | kargasok
# Processing Record 22 of Set 13 | kapit
# Processing Record 23 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 13 | mpraeso
# Processing Record 25 of Set 13 | elizabeth city
# Processing Record 26 of Set 13 | vardo
# Processing Record 27 of Set 13 | razole
# Processing Record 28 of Set 13 | poso
# Processing Record 29 of Set 13 | mincivan
# Processing Record 30 of Set 13 | leirvik
# Processing Record 31 of Set 13 | neenah
# Processing Record 32 of Set 13 | rock springs
# Processing Record 33 of Set 13 | halifax
# Processing Record 34 of Set 13 | dir
# Processing Record 35 of Set 13 | kilinochchi
# Processing Record 36 of Set 13 | richards bay
# Processing Record 37 of Set 13 | boyolangu
# Processing Record 38 of Set 13 | abilene
# Processing Record 39 of Set 13 | bodden town
# Processing Record 40 of Set 13 | burica
# City not found. Skipping...
# Processing Record 41 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 13 | bolobo
# Processing Record 43 of Set 13 | safaga
# Processing Record 44 of Set 13 | maraba
# Processing Record 45 of Set 13 | tadine
# Processing Record 46 of Set 13 | college
# Processing Record 47 of Set 13 | puerto suarez
# Processing Record 48 of Set 13 | vernon
# Processing Record 49 of Set 13 | manta
# Processing Record 50 of Set 13 | chalus
# Processing Record 1 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 14 | mollendo
# Processing Record 3 of Set 14 | holovyne
# Processing Record 4 of Set 14 | marau
# Processing Record 5 of Set 14 | puerto colombia
# Processing Record 6 of Set 14 | predivinsk
# Processing Record 7 of Set 14 | nizhniy odes
# Processing Record 8 of Set 14 | kiama
# Processing Record 9 of Set 14 | norman wells
# Processing Record 10 of Set 14 | berbera
# Processing Record 11 of Set 14 | abu kamal
# Processing Record 12 of Set 14 | warrington
# Processing Record 13 of Set 14 | ilinskiy
# Processing Record 14 of Set 14 | cedral
# Processing Record 15 of Set 14 | pavlovskiy
# Processing Record 16 of Set 14 | luganville
# Processing Record 17 of Set 14 | tautira
# Processing Record 18 of Set 14 | najran
# Processing Record 19 of Set 14 | shenjiamen
# Processing Record 20 of Set 14 | isangel
# Processing Record 21 of Set 14 | at-bashi
# Processing Record 22 of Set 14 | ahuimanu
# Processing Record 23 of Set 14 | balakhta
# Processing Record 24 of Set 14 | dambulla
# Processing Record 25 of Set 14 | bosconia
# Processing Record 26 of Set 14 | kabanjahe
# Processing Record 27 of Set 14 | bousso
# Processing Record 28 of Set 14 | teixeira
# Processing Record 29 of Set 14 | cooma
# Processing Record 30 of Set 14 | ziro
# Processing Record 31 of Set 14 | nevelsk
# Processing Record 32 of Set 14 | pasni
# Processing Record 33 of Set 14 | santa lucia
# Processing Record 34 of Set 14 | nzerekore
# Processing Record 35 of Set 14 | hay river
# Processing Record 36 of Set 14 | wanaka
# Processing Record 37 of Set 14 | eyl
# Processing Record 38 of Set 14 | overyata
# Processing Record 39 of Set 14 | kununurra
# Processing Record 40 of Set 14 | antsohihy
# Processing Record 41 of Set 14 | salta
# Processing Record 42 of Set 14 | xam nua
# Processing Record 43 of Set 14 | khapa
# Processing Record 44 of Set 14 | uthal
# Processing Record 45 of Set 14 | livingston
# Processing Record 46 of Set 14 | utinga
# Processing Record 47 of Set 14 | garowe
# Processing Record 48 of Set 14 | san cristobal
# Processing Record 49 of Set 14 | foam lake
# Processing Record 50 of Set 14 | thunder bay
# Processing Record 1 of Set 15 | gillette
# Processing Record 2 of Set 15 | pandamatenga
# Processing Record 3 of Set 15 | meridian
# Processing Record 4 of Set 15 | baillif
# Processing Record 5 of Set 15 | toamasina
# Processing Record 6 of Set 15 | milkovo
# Processing Record 7 of Set 15 | mersing
# Processing Record 8 of Set 15 | sisimiut
# Processing Record 9 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 15 | emiliano zapata
# Processing Record 11 of Set 15 | asyut
# Processing Record 12 of Set 15 | istanbul
# Processing Record 13 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 15 | nevsehir
# Processing Record 15 of Set 15 | carutapera
# Processing Record 16 of Set 15 | prajeni
# Processing Record 17 of Set 15 | hengshan
# Processing Record 18 of Set 15 | ballina
# Processing Record 19 of Set 15 | kashi
# Processing Record 20 of Set 15 | arman
# Processing Record 21 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 15 | schwalmstadt
# Processing Record 23 of Set 15 | paita
# Processing Record 24 of Set 15 | nikolayevsk-na-amure
# Processing Record 25 of Set 15 | doka
# Processing Record 26 of Set 15 | pitiquito
# Processing Record 27 of Set 15 | xinyang
# Processing Record 28 of Set 15 | pastos bons
# Processing Record 29 of Set 15 | bilma
# Processing Record 30 of Set 15 | uyskoye
# Processing Record 31 of Set 15 | krasnoselkup
# Processing Record 32 of Set 15 | kulhudhuffushi
# Processing Record 33 of Set 15 | santa maria
# Processing Record 34 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 35 of Set 15 | sovetskaya
# Processing Record 36 of Set 15 | zhanakorgan
# Processing Record 37 of Set 15 | kundgol
# Processing Record 38 of Set 15 | ryotsu
# Processing Record 39 of Set 15 | bagan
# Processing Record 40 of Set 15 | domanivka
# Processing Record 41 of Set 15 | southbridge
# Processing Record 42 of Set 15 | tabou
# Processing Record 43 of Set 15 | kirakira
# Processing Record 44 of Set 15 | toucheng
# Processing Record 45 of Set 15 | horta
# Processing Record 46 of Set 15 | mayo
# Processing Record 47 of Set 15 | tymovskoye
# Processing Record 48 of Set 15 | rovaniemi
# Processing Record 49 of Set 15 | luanda
# Processing Record 50 of Set 15 | carmo do paranaiba
# Processing Record 1 of Set 16 | sainte-suzanne
# Processing Record 2 of Set 16 | marawi
# Processing Record 3 of Set 16 | kurumkan
# Processing Record 4 of Set 16 | emerald
# Processing Record 5 of Set 16 | umea
# Processing Record 6 of Set 16 | veraval
# Processing Record 7 of Set 16 | srednekolymsk
# Processing Record 8 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 16 | san cosme y damian
# Processing Record 10 of Set 16 | flinders
# Processing Record 11 of Set 16 | zolotinka
# City not found. Skipping...
# Processing Record 12 of Set 16 | tuggurt
# City not found. Skipping...
# Processing Record 13 of Set 16 | antofagasta
# Processing Record 14 of Set 16 | ust-kut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#checking len of city_data
len(city_data)
# Out:
# 693

# %%
#read in city_data to city_data_df
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Plettenberg Bay -34.0527   23.3716     56.05        86          95
# 1        Esperance -33.8667  121.9000     60.30        63          38
# 2  Arraial Do Cabo -22.9661  -42.0278     69.82        95          76
# 3       Butaritari   3.0707  172.7902     82.80        75         100
# 4          Rikitea -23.1203 -134.9692     73.26        69          29
#
#    Wind Speed Country Current Description
# 0       11.43      ZA     overcast clouds
# 1       25.48      AU    scattered clouds
# 2       12.55      BR       moderate rain
# 3       16.98      KI     overcast clouds
# 4       20.58      PF    scattered clouds

# %%
#reorder city_data_df
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Plettenberg Bay      ZA -34.0527   23.3716     56.05        86          95
# 1        Esperance      AU -33.8667  121.9000     60.30        63          38
# 2  Arraial Do Cabo      BR -22.9661  -42.0278     69.82        95          76
# 3       Butaritari      KI   3.0707  172.7902     82.80        75         100
# 4          Rikitea      PF -23.1203 -134.9692     73.26        69          29
#
#    Wind Speed Current Description
# 0       11.43     overcast clouds
# 1       25.48    scattered clouds
# 2       12.55       moderate rain
# 3       16.98     overcast clouds
# 4       20.58    scattered clouds

# %%
#Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
#Export the City_Data into CSV
city_data_df.to_csv(output_data_file,index_label="City_ID")
